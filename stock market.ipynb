# %%
import requests
import json

# Define the base URL
base_url = "https://www.nseindia.com/api/historical/cm/equity?symbol=CENTRUM&series=[%22EQ%22]&from=01-01-2019&to=01-01-2020"

# Define the headers
headers = {
    "accept": "*/*",
    "accept-language": "en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7,hi;q=0.6",
    "priority": "u=1, i",
    "sec-ch-ua": "\"Not/A)Brand\";v=\"8\", \"Chromium\";v=\"126\", \"Google Chrome\";v=\"126\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "cookie": "nsit=FmC9Y9RP9rTeGDwUgBcoxg58; AKA_A2=A; defaultLang=en; _ga=GA1.1.1875869995.1720932973; ak_bmsc=E7326ABD5F0110A760FF3E0EB74D8074~000000000000000000000000000000~...; _abck=A256CB3775D116F495312270A9D3A6D8~0~...~-1~-1~-1; nseQuoteSymbols=[{\"symbol\":\"Centrum Capital Limited\",\"identifier\":null,\"type\":\"equity\"},{\"symbol\":\"Centum Electronics Limited\",\"identifier\":null,\"type\":\"equity\"},{\"symbol\":\"Chemplast Sanmar Limited\",\"identifier\":null,\"type\":\"equity\"},{\"symbol\":\"Cipla Limited\",\"identifier\":null,\"type\":\"equity\"},{\"symbol\":\"Divi&#39; nseappid=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJhcGkubnNlIiwiYXVkIjoiYXBpLm5zZSIsImlhdCI6MTcyMDkzNDE5OCwiZXhwIjoxNzIwOTQxMzk4fQ.I6WB1VGpNTAJP5eiRwVIgq9dapy1-cF7KG3tsSvsMag; bm_sz=3829617EF755DA6DB7DB2236A4BE8E3A~...~4342834~3289144; _ga_87M7PJ3R97=GS1.1.1720932973.1.1.1720934235.14.0.0; RT=\"z=1&dm=nseindia.com&si=f482b2d0-3f42-4330-abc2-a4386b7ff90a&ss=lyl3sav4&sl=0&se=8c&tt=0&bcn=%2F%2F684d0d4c.akstat.io%2F\"; bm_sv=82955C52B43EDE2A862DB948C355F0F6~~1",
    "Referer": "https://www.nseindia.com/get-quotes/equity?symbol=CENTRUM",
    "Referrer-Policy": "strict-origin-when-cross-origin"
}

# Make the request
response = requests.get(base_url, headers=headers)

# Check the status code and process the response
if response.status_code == 200:
    js_data = json.loads(response.text)
    js_arr = []  # Initialize an empty list to store the data
    for api in js_data.get("data", []):
        date = str(api["DATE"])
        openn = str(api["OPEN"])
        high = str(api["HIGH"])
        low = str(api["LOW"])
        close = str(api["CLOSE"])
        no_of_shares = str(api["NO OF SHARES"])
        no_of_trades = str(api["NO OF TRADES"])

        new_js = {
            "DATE": date,
            "OPEN": openn,
            "HIGH": high,
            "LOW": low,
            "CLOSE": close,
            "NO OF SHARES": no_of_shares,
            "NO OF TRADES": no_of_trades
        }
        js_arr.append(new_js)
else:
    print("Failed to retrieve data")
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#
# ...
