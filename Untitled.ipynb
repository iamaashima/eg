# %%
import requests
import json

# Define the base URL
base_url = "https://www.nseindia.com/api/historical/cm/equity?symbol=CENTRUM&series=[%22EQ%22]&from=01-01-2019&to=01-01-2020"

# Define the headers
headers = {
    "accept": "*/*",
    "accept-language": "en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7,hi;q=0.6",
    "priority": "u=1, i",
    "sec-ch-ua": "\"Not/A)Brand\";v=\"8\", \"Chromium\";v=\"126\", \"Google Chrome\";v=\"126\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "Referer": "https://www.nseindia.com/get-quotes/equity?symbol=CENTRUM",
    "Referrer-Policy": "strict-origin-when-cross-origin"
}

# Initialize a session
session = requests.Session()

# Update the session headers
session.headers.update(headers)

# Define the cookie (use your own cookie value here)
cookies = {
    "_ga": "GA1.1.1875869995.1720932973",
    "nseQuoteSymbols": '[{"symbol":"Centrum Capital Limited","identifier":null,"type":"equity"},{"symbol":"Centum Electronics Limited","identifier":null,"type":"equity"},{"symbol":"Chemplast Sanmar Limited","identifier":null,"type":"equity"},{"symbol":"Cipla Limited","identifier":null,"type":"equity"},{"symbol":"Divi&#39;"]',
    "nsit": "wMQFp5AE6zq2yPmjipqcgLon",
    "AKA_A2": "A",
    "_abck": "A256CB3775D116F495312270A9D3A6D8~0~...~-1~-1~-1",
    "defaultLang": "en",
    "ak_bmsc": "B20CDB0E5D3FB7FE6B1842A8D41D127A~000000000000000000000000000000~...",
    "nseappid": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJhcGkubnNlIiwiYXVkIjoiYXBpLm5zZSIsImlhdCI6MTcyMDk2NTY2OCwiZXhwIjoxNzIwOTcyODY4fQ.oGwt3bi8bEJ5GYrTRqb9Ord5dvd3AaATE9jpV9hoszs",
    "bm_sz": "123F0E7682A06287F3F5274DD0ADB990~...~4473409~4539957",
    "RT": '\"z=1&dm=nseindia.com&si=f482b2d0-3f42-4330-abc2-a4386b7ff90a&ss=lylmia1t&sl=3&se=8c&tt=34u&bcn=%2F%2F684d0d48.akstat.io%2F&nu=kpaxjfo&cl=qvx&ld=ow4\"',
    "_ga_87M7PJ3R97": "GS1.1.1720965641.4.1.1720965674.27.0.0",
    "bm_sv": "3497AB6640F90E7ECA9C7D8BAD9ADC62~~1"
}

# Update the session cookies
session.cookies.update(cookies)

# Make the request
response = session.get(base_url)

# Check the status code and process the response
if response.status_code == 200:
    js_data = json.loads(response.text)
    print(js_data)
else:
    print(f"Failed to retrieve data: {response.status_code}")
    print(response.text)

# %%
js_arr = []  # Initialize an empty list to store the data
for api in js_data.get("data", []):
        date = str(api["DATE"])
        openn = str(api["OPEN"])
        high = str(api["HIGH"])
        low = str(api["LOW"])
        close = str(api["CLOSE"])
        no_of_shares = str(api["NO OF SHARES"])
        no_of_trades = str(api["NO OF TRADES"])

        new_js = {
            "DATE": date,
            "OPEN": openn,
            "HIGH": high,
            "LOW": low,
            "CLOSE": close,
            "NO OF SHARES": no_of_shares,
            "NO OF TRADES": no_of_trades
        }
        js_arr.append(new_js)
